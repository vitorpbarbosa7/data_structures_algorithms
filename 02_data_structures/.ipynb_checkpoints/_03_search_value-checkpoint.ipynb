# %%
new_list = [1,2,3]
result = new_list[0]

# %%
if 1 in new_list:print(True)
# Out:
# True

# %% [markdown]
# # 3 types of insert operations
#
# - True Insert, using index value, insert element anywhere in the list - Linear Runtime O(n)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - appending, simply add the item to the end of the list, so in several languages this is constant time O(1)

# %% [markdown]
# ### Allocates 4 spaces

# %%
numbers = []

# %%
numbers.__sizeof__()
# Out:
# 40

# %%
len(numbers)
# Out:
# 0

# %%
numbers.append(2)

# %%
numbers.__sizeof__()
# Out:
# 72

# %%
len(numbers)
# Out:
# 1

# %%
### Memmory allocation

# %%
numbers.append(200)

# %%
numbers.__sizeof__()
# Out:
# 72

# %%
len(numbers)
# Out:
# 2

# %%
numbers.append(400)

# %%
numbers.__sizeof__()
# Out:
# 72

# %%
numbers.append(500)

# %%
numbers.__sizeof__()
# Out:
# 72

# %%
numbers.append(800)

# %% [markdown]
# ### Quando chegamos no quinto elemento, finalmente ele resolveu incrementar mais 4

# %%
numbers
# Out:
# [2, 200, 400, 500, 800]

# %%
numbers.__sizeof__()
# Out:
# 104

# %% [markdown]
# In python, the memory allocation pattern is this:
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Ammortized Constant Space Complexity
#
# - Algumas operações demandam aumento de alocação de memória e outras não

# %% [markdown]
# # Add list to another

# %%
numbers = [1]

# %%
numbers
# Out:
# [1]

# %%
numbers.extend([4,5,6])

# %%
numbers
# Out:
# [1, 4, 5, 6]

# %% [markdown]
# ### O(k) k  numbers added

# %% [markdown]
# ## Delete operations O(n) - Linear Runtime - shift elements to the left
