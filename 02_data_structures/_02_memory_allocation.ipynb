# %%
new_list = [1,2,3]

# %%
type(new_list)
# Out:
# list

# %% [markdown]
# ### In python, it is used pointers to point to where the actuval value is in memory

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
new_list[2]
# Out:
# 3

# %%
new_list[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-a54e104f1265> in <module>
# ----> 1 new_list[3]
#
# IndexError: list index out of range

# %%
try:
    new_list[3]
except Exception as e:
    print(f' Exception {e} was raised, so you must \
pass a index between 0 and {len(new_list) - 1}')
# Out:
#  Exception list index out of range was raised, so you must pass a index between 0 and 2

# %% [markdown]
#  # contains

# %%
if 1 in new_list: print(True)
# Out:
# True

# %%
for n in new_list:
    if n == 1:
        print(True)
        break
# Out:
# True

# %%
# in works because contains is implemented for list type, this data structure
dir(new_list)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
print(new_list.__contains__)
# Out:
# <method-wrapper '__contains__' of list object at 0x7f17c03579b0>
